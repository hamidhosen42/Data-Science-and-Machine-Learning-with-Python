# %% [markdown]
# ## Implot

# %% [markdown]
# The lmplot plot shows the line along with datapoints on the 2d space. By specifying x and y you can set the horizontal and vertical labels repsectively.

# %% [markdown]
# ### Scatter plot with regression line(by default).

# %%
# we import seaborn,visualization library
import seaborn as sns;
sns.set(color_codes=True)
import matplotlib.pyplot as plt;
import pandas as pd;

# Load CSV and columns
chirp_data = pd.read_csv("Seaborn Implot data set/chirps.csv")

g = sns.lmplot(x="Chirps_15s", y="Temp_C", data=chirp_data)
plt.title('Cricket Chirp and Temperature')
plt.show()

# %% [markdown]
# ### Scatter plot without regression line

# %%
# we import seaborn,visualization library
import seaborn as sns;
import matplotlib.pyplot as plt;
import pandas as pd;

# Load CSV and columns
chirp_data = pd.read_csv("Seaborn Implot data set/chirps.csv")

g = sns.lmplot(x="Chirps_15s", y="Temp_C",fit_reg = False, data=chirp_data)
plt.title('Cricket Chirp and Temperature')
plt.show()
