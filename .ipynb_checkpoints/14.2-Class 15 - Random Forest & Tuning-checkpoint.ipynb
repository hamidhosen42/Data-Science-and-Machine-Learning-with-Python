# %%
import pandas as pd # data frame library
import seaborn as sns # data visialization library
import matplotlib.pyplot as plt
import numpy
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('uci breast cancer dataset.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df = df.drop(['id','Unnamed: 32'], axis = 'columns')

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
#
# %%
x = df.drop('diagnosis',axis=1)

# %%
y = df[['diagnosis']]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,train_size=.75, random_state=42)

# %%
ytest
# Out:
#     diagnosis
# 204         B
# 70          M
# 131         M
# 431         B
# 540         B
# ..        ...
# 89          B
# 199         M
# 411         B
# 18          M
# 390         B
#
# [143 rows x 1 columns]

# %%
ytest.shape
# Out:
# (143, 1)

# %%
xtest.shape
# Out:
# (143, 30)

# %% [markdown]
# # Apply Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain) #train the model with 70% of data from dataset
# Out:
# DecisionTreeClassifier()

# %%
pred = dt.predict(xtest) # pred is corrsponding to ytest

# %%
ytest
# Out:
#     diagnosis
# 204         B
# 70          M
# 131         M
# 431         B
# 540         B
# ..        ...
# 89          B
# 199         M
# 411         B
# 18          M
# 390         B
#
# [143 rows x 1 columns]

# %%
pred # Predicted value of Y
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B'],
#       dtype=object)

# %%
import numpy as np
np.array(ytest) # Actual Value of Y
# Out:
# array([['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['B'],
#        ['B'],
#        ['M'],
#        ['B'],
#        ['M'],
#        ['B']], dtype=object)

# %%
dt.score(xtest,ytest)
# Out:
# 0.9440559440559441

# %% [markdown]
# # Evaluate the ML model

# %%
from sklearn.metrics import classification_report , accuracy_score, confusion_matrix, plot_roc_curve

# %%
classification_report(ytest,pred)
# Out:
# '              precision    recall  f1-score   support\n\n           B       0.98      0.93      0.95        89\n           M       0.90      0.96      0.93        54\n\n    accuracy                           0.94       143\n   macro avg       0.94      0.95      0.94       143\nweighted avg       0.95      0.94      0.94       143\n'

# %%
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.98      0.93      0.95        89
#            M       0.90      0.96      0.93        54
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.95      0.94       143
# weighted avg       0.95      0.94      0.94       143

# %%
test_confusion_matrix = confusion_matrix(ytest,pred)

# %%
test_confusion_matrix
# Out:
# array([[83,  6],
#        [ 2, 52]], dtype=int64)

# %%
sns.heatmap(test_confusion_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
tp, fp, fn, tn = confusion_matrix(ytest,pred).reshape(-1)

# %%
dt.score(xtest,ytest)
# Out:
# 0.9440559440559441

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier() # default parameters, 100 Tree = n_estimators=100

# %%
clf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
clf.score(xtest, ytest)
# Out:
# 0.965034965034965

# %% [markdown]
# # Some dataset for practice

# %%
#https://scikit-learn.org/stable/datasets/toy_dataset.html
#https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
#https://scikit-learn.org/stable/datasets/real_world.html

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#https://scikit-learn.org/0.16/modules/generated/sklearn.grid_search.RandomizedSearchCV.html

# %% [markdown]
# # Randomized Search CV

# %%
# creating param_distributions for random forest
import numpy as np
trees = np.random.randint(15,150,30)

# %%
trees
# Out:
# array([ 26,  83, 105,  31, 103, 110,  39, 115, 110, 124,  85, 138, 122,
#         62,  70, 127, 114,  38,  45, 109,  27,  56, 114,  92,  65, 133,
#         92,  45,  49, 134])

# %%
max_features = ['sqrt','log2']
max_depth = np.random.randint(2,12,50)
criterion = ['gini','entropy']
min_samples_split = [2,3,4]

grids = {
    'n_estimators' : trees,
    'max_features' : max_features,
    'max_depth' : max_depth,
    'criterion' : criterion,
    'min_samples_split' : min_samples_split
}

# %%
print(grids)
# Out:
# {'n_estimators': array([ 26,  83, 105,  31, 103, 110,  39, 115, 110, 124,  85, 138, 122,
#         62,  70, 127, 114,  38,  45, 109,  27,  56, 114,  92,  65, 133,
#         92,  45,  49, 134]), 'max_features': ['sqrt', 'log2'], 'max_depth': array([ 7, 11,  3, 11,  7,  2,  8, 10,  9,  8,  5, 10, 11, 11,  9,  6,  8,
#        10,  7, 11,  4,  4,  9,  7,  2, 11,  7,  4,  9,  7,  8,  3,  7, 11,
#         9,  8,  3,  7,  5,  2,  7,  2,  3,  8,  3,  9,  7,  5,  5,  3]), 'criterion': ['gini', 'entropy'], 'min_samples_split': [2, 3, 4]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rcv = RandomizedSearchCV(clf, grids, n_iter=200, cv=3)

# %%
rcv.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=200,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([ 7, 11,  3, 11,  7,  2,  8, 10,  9,  8,  5, 10, 11, 11,  9,  6,  8,
#        10,  7, 11,  4,  4,  9,  7,  2, 11,  7,  4,  9,  7,  8,  3,  7, 11,
#         9,  8,  3,  7,  5,  2,  7,  2,  3,  8,  3,  9,  7,  5,  5,  3]),
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': array([ 26,  83, 105,  31, 103, 110,  39, 115, 110, 124,  85, 138, 122,
#         62,  70, 127, 114,  38,  45, 109,  27,  56, 114,  92,  65, 133,
#         92,  45,  49, 134])})

# %%
rcv.cv_results_
# Out:
# {'mean_fit_time': array([0.20080868, 0.25065033, 0.23271243, 0.04557021, 0.14294004,
#         0.14029249, 0.19447827, 0.19279806, 0.20213715, 0.23801812,
#         0.20509545, 0.16754111, 0.09075904, 0.19913324, 0.26133442,
#                     56, 124, 39, 124, 62, 27, 115, 83, 83, 105, 26, 70, 38,
#                     26, 45, 38, 49, 92, 85, 38, 92, 114, 115, 115, 85, 114,
#                     49, 45, 45, 70, 133, 103, 85, 122, 70, 110, 27, 114,
#                     115, 127, 114, 114, 92, 92, 56, 49, 103, 127, 39, 114,
#                     110, 27, 31, 105, 138, 138, 31, 45, 65, 134, 122, 134,
#                     115, 92, 31, 85],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[4, 3, 3, 2, 3, 2, 3, 4, 3, 3, 3, 2, 3, 2, 2, 2, 2, 2,
#                     3, 3, 3, 4, 2, 4, 2, 2, 3, 4, 4, 4, 3, 3, 2, 4, 3, 2,
#                     4, 3, 2, 4, 2, 3, 2, 4, 4, 2, 2, 3, 2, 3, 3, 2, 2, 3,
#                     4, 3, 3, 3, 4, 4, 2, 3, 4, 4, 4, 4, 2, 2, 4, 2, 4, 3,
#                     4, 3, 4, 2, 4, 4, 4, 4, 2, 3, 3, 4, 4, 3, 2, 3, 4, 3,
#                     2, 4, 2, 2, 4, 2, 3, 2, 2, 4, 4, 2, 2, 2, 4, 3, 4, 2,
#                     3, 3, 3, 3, 2, 3, 2, 3, 3, 2, 4, 4, 2, 3, 3, 3, 2, 3,
#                     3, 4, 4, 2, 3, 2, 3, 3, 3, 4, 3, 4, 3, 3, 2, 2, 2, 2,
#                     4, 2, 3, 3, 4, 4, 4, 4, 2, 4, 3, 3, 2, 3, 3, 2, 4, 4,
#                     3, 3, 2, 3, 3, 2, 3, 2, 2, 3, 3, 2, 4, 3, 4, 2, 3, 3,
#                     3, 2, 2, 3, 3, 3, 2, 2, 4, 3, 3, 4, 3, 3, 3, 4, 4, 2,
#                     2, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['log2', 'log2', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'sqrt', 'log2', 'sqrt',
#                     'sqrt', 'log2', 'log2', 'log2', 'log2', 'log2', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2',
#                     'log2', 'log2', 'log2', 'log2', 'log2', 'sqrt', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'log2',
#                     'sqrt', 'log2', 'log2', 'sqrt', 'log2', 'log2', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'log2', 'sqrt', 'sqrt', 'log2', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'log2', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'log2', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2',
#                     'log2', 'log2', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'log2', 'log2', 'sqrt', 'log2', 'log2', 'sqrt',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'sqrt', 'sqrt', 'log2', 'sqrt'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[8, 8, 7, 2, 2, 11, 3, 10, 7, 10, 3, 10, 11, 7, 5, 6,
#                     11, 7, 9, 3, 2, 4, 11, 8, 4, 4, 5, 4, 7, 7, 8, 3, 11,
#                     9, 2, 2, 7, 11, 11, 2, 7, 8, 6, 9, 3, 5, 10, 3, 11, 11,
#                     9, 8, 11, 3, 11, 11, 3, 3, 2, 9, 11, 2, 2, 7, 7, 10, 3,
#                     2, 7, 7, 8, 7, 7, 9, 3, 9, 10, 3, 4, 5, 6, 8, 7, 7, 4,
#                     7, 3, 7, 4, 5, 4, 8, 5, 4, 7, 10, 8, 8, 4, 2, 11, 10,
#                     5, 11, 8, 11, 5, 11, 5, 7, 2, 7, 3, 4, 5, 3, 11, 5, 8,
#                     6, 7, 3, 7, 6, 9, 7, 9, 5, 9, 2, 11, 10, 8, 9, 5, 3, 4,
#                     11, 7, 3, 7, 7, 2, 4, 8, 8, 9, 11, 7, 11, 4, 3, 7, 5,
#                     8, 3, 11, 5, 11, 6, 11, 7, 7, 7, 2, 7, 9, 4, 9, 5, 7,
#                     7, 10, 5, 5, 11, 5, 9, 7, 8, 9, 5, 3, 11, 2, 7, 2, 8,
#                     8, 7, 7, 5, 7, 7, 11, 11, 3, 3, 10, 5],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['entropy', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'entropy', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'entropy', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'entropy', 'gini',
#                     'gini', 'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'gini',
#                     'entropy', 'gini', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'entropy', 'gini',
#                     'gini', 'gini', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'gini', 'entropy',
#                     'entropy', 'gini', 'gini', 'entropy', 'entropy',
#                     'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'entropy', 'gini',
#                     'gini', 'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'gini', 'entropy', 'entropy', 'entropy',
#                     'gini', 'gini', 'entropy', 'entropy', 'entropy',
#                     'gini', 'gini', 'entropy', 'entropy', 'gini', 'gini',
#                     'gini', 'entropy', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'gini', 'gini', 'entropy', 'entropy', 'gini', 'gini'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 114,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 134,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 138,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 27,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 85,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 85,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 103,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 105,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 109,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 133,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 134,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 49,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 134,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 62,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 27,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 105,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 65,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 134,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 114,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'n_estimators': 138,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 65,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 49,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 138,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 115,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 56,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'n_estimators': 26,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 31,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 105,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 105,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 134,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 110,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 114,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'entropy'},
#   {'n_estimators': 83,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 127,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 56,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 49,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 127,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 114,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 56,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 39,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 124,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 127,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 134,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 38,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 38,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 70,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 110,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 62,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 31,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 103,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'n_estimators': 62,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 85,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 26,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 26,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 109,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 45,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 114,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 127,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 31,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'n_estimators': 31,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 56,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 49,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 39,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 114,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'n_estimators': 138,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 70,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 56,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 45,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'n_estimators': 133,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'n_estimators': 45,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 114,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 49,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 138,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'n_estimators': 56,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 105,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 39,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 103,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 127,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 85,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'n_estimators': 31,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 65,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'entropy'},
#   {'n_estimators': 49,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 134,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 110,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'n_estimators': 92,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 56,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 110,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 115,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 70,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 124,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 49,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'n_estimators': 127,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'n_estimators': 122,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 9,
#    'criterion': 'gini'},
#   {'n_estimators': 56,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'},
#   {'n_estimators': 124,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 3,
#    'criterion': 'gini'},
#   {'n_estimators': 39,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'n_estimators': 124,
#    'min_samples_split': 4,
#    'max_features': 'log2',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 62,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 27,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 115,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 83,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'gini'},
#   {'n_estimators': 83,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'n_estimators': 105,
#    'min_samples_split': 2,
# ...
#    'criterion': 'entropy'},
#   {'n_estimators': 45,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'entropy'},
#   {'n_estimators': 65,
#    'min_samples_split': 3,
#    'max_features': 'log2',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 134,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 7,
#    'criterion': 'entropy'},
#   {'n_estimators': 122,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 134,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 11,
#    'criterion': 'gini'},
#   {'n_estimators': 115,
#    'min_samples_split': 4,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 92,
#    'min_samples_split': 2,
#    'max_features': 'sqrt',
#    'max_depth': 3,
#    'criterion': 'entropy'},
#   {'n_estimators': 31,
#    'min_samples_split': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'n_estimators': 85,
#    'min_samples_split': 3,
#    'max_features': 'sqrt',
#    'max_depth': 5,
#    'criterion': 'gini'}],
#  'split0_test_score': array([0.92957746, 0.94366197, 0.93661972, 0.94366197, 0.92957746,
#         0.96478873, 0.93661972, 0.94366197, 0.93661972, 0.95774648,
#         0.93661972, 0.95774648, 0.94366197, 0.95070423, 0.94366197,
#         0.94366197, 0.94366197, 0.94366197, 0.94366197, 0.93661972,
#         0.93661972, 0.94366197, 0.94366197, 0.95774648, 0.94366197,
#         0.95070423, 0.95070423, 0.93661972, 0.94366197, 0.95070423,
#         0.94366197, 0.93661972, 0.94366197, 0.94366197, 0.93661972,
#         0.93661972, 0.93661972, 0.94366197, 0.95070423, 0.92957746,
#         0.94366197, 0.94366197, 0.93661972, 0.93661972, 0.93661972,
#         0.95070423, 0.95070423, 0.93661972, 0.94366197, 0.94366197,
#         0.94366197, 0.95070423, 0.95774648, 0.92957746, 0.93661972,
#         0.96478873, 0.93661972, 0.93661972, 0.92957746, 0.93661972,
#         0.95070423, 0.94366197, 0.92957746, 0.92957746, 0.94366197,
#         0.95774648, 0.93661972, 0.92957746, 0.95774648, 0.95774648,
#         0.95070423, 0.95774648, 0.93661972, 0.95070423, 0.93661972,
#         0.95070423, 0.95070423, 0.93661972, 0.93661972, 0.92957746,
#         0.95774648, 0.95070423, 0.93661972, 0.97887324, 0.94366197,
#         0.93661972, 0.93661972, 0.94366197, 0.94366197, 0.96478873,
ean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.200809      0.007513         0.014627        0.000470
# 1         0.250650      0.014045         0.018295        0.001258
# 2         0.232712      0.013489         0.018617        0.001694
# 3         0.045570      0.005240         0.005638        0.000463
# 4         0.142940      0.012678         0.012644        0.001709
# ..             ...           ...              ...             ...
# 195       0.221851      0.002095         0.012134        0.000040
# 196       0.190402      0.006011         0.017776        0.002168
# 197       0.159025      0.003700         0.008739        0.007433
# 198       0.054988      0.008748         0.007202        0.006436
# 199       0.132505      0.001449         0.010806        0.000962
#
#     param_n_estimators param_min_samples_split param_max_features  \
# 0                  114                       4               log2
# 1                  134                       3               log2
# 2                  138                       3               log2
# 3                   27                       2               log2
# 4                   85                       3               sqrt
# ..                 ...                     ...                ...
# 195                134                       4               sqrt
# 196                115                       4               sqrt
# 197                 92                       2               sqrt
# 198                 31                       2               log2
# 199                 85                       3               sqrt
#
#     param_max_depth param_criterion  \
# 0                 8         entropy
# 1                 8         entropy
# 2                 7            gini
# 3                 2            gini
# 4                 2            gini
# ..              ...             ...
# 195              11            gini
# 196               3         entropy
# 197               3         entropy
# 198              10            gini
# 199               5            gini
#
#                                                 params  split0_test_score  \
# 0    {'n_estimators': 114, 'min_samples_split': 4, ...           0.929577
# 1    {'n_estimators': 134, 'min_samples_split': 3, ...           0.943662
# 2    {'n_estimators': 138, 'min_samples_split': 3, ...           0.936620
# 3    {'n_estimators': 27, 'min_samples_split': 2, '...           0.943662
# 4    {'n_estimators': 85, 'min_samples_split': 3, '...           0.929577
# ..                                                 ...                ...
# 195  {'n_estimators': 134, 'min_samples_split': 4, ...           0.957746
# 196  {'n_estimators': 115, 'min_samples_split': 4, ...           0.943662
# 197  {'n_estimators': 92, 'min_samples_split': 2, '...           0.929577
# 198  {'n_estimators': 31, 'min_samples_split': 2, '...           0.936620
# 199  {'n_estimators': 85, 'min_samples_split': 3, '...           0.950704
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             0.964789           0.950704         0.948357        0.014470
# 1             0.957746           0.957746         0.953052        0.006640
# 2             0.964789           0.950704         0.950704        0.011500
# 3             0.936620           0.936620         0.938967        0.003320
# 4             0.922535           0.936620         0.929577        0.005750
# ..                 ...                ...              ...             ...
# 195           0.957746           0.957746         0.957746        0.000000
# 196           0.943662           0.936620         0.941315        0.003320
# 197           0.950704           0.950704         0.943662        0.009959
# 198           0.936620           0.957746         0.943662        0.009959
# 199           0.943662           0.943662         0.946009        0.003320
#
#      rank_test_score
# 0                110
# 1                 67
# 2                 84
# 3                180
# 4                193
# ..               ...
# 195               24
# 196              175
# 197              164
# 198              164
# 199              140
#
# [200 rows x 16 columns]

# %%
rcv.best_score_
# Out:
# 0.9647887323943661

# %%
rcv.best_params_
# Out:
# {'n_estimators': 26,
#  'min_samples_split': 2,
#  'max_features': 'sqrt',
#  'max_depth': 6,
#  'criterion': 'entropy'}

# %%
clf2 = rcv.best_estimator_

# %%
clf2.fit(xtrain, ytrain) # training again
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=6, max_features='sqrt',
#                        n_estimators=26)

# %%
clf2.score(xtest, ytest)
# Out:
# 0.972027972027972
