# %% [markdown]
# # All about Decision Tree

# %% [markdown]
# A decision tree is a very specific type of probability tree that enables you to make a decision about some
# kind of process. It is used to break down complex problems or branches. Each branch of the decision tree
# could be a possible outcome.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./DataSet/game data.csv')

# %%
df
# Out:
#    Days Outlook Temprature  Routine Wear Jacket?
# 0     1   Sunny       Cold  Indoor            No
# 1     2  Cloudy       Cold  Indoor           Yes
# 2     3  Cloudy       Warm  Outdoor           No
# 3     4   Sunny       Cold  Outdoor          Yes
# 4     5  Cloudy       Cold  Outdoor          Yes
# 5     6   Sunny       Warm  Outdoor           No
# 6     7  Cloudy       Warm  Indoor            No
# 7     8   Sunny       Warm  Indoor            No

# %%
df.drop('Days',axis=1,inplace=True)

# %%
df
# Out:
#   Outlook Temprature  Routine Wear Jacket?
# 0   Sunny       Cold  Indoor            No
# 1  Cloudy       Cold  Indoor           Yes
# 2  Cloudy       Warm  Outdoor           No
# 3   Sunny       Cold  Outdoor          Yes
# 4  Cloudy       Cold  Outdoor          Yes
# 5   Sunny       Warm  Outdoor           No
# 6  Cloudy       Warm  Indoor            No
# 7   Sunny       Warm  Indoor            No

# %%
x=df.drop('Wear Jacket?',axis=1)

# %%
x
# Out:
#   Outlook Temprature  Routine
# 0   Sunny       Cold  Indoor
# 1  Cloudy       Cold  Indoor
# 2  Cloudy       Warm  Outdoor
# 3   Sunny       Cold  Outdoor
# 4  Cloudy       Cold  Outdoor
# 5   Sunny       Warm  Outdoor
# 6  Cloudy       Warm  Indoor
# 7   Sunny       Warm  Indoor

# %%
y=df['Wear Jacket?']
y
# Out:
# 0     No
# 1    Yes
# 2     No
# 3    Yes
# 4    Yes
# 5     No
# 6     No
# 7     No
# Name: Wear Jacket?, dtype: object

# %% [markdown]
# ## Level Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for col in x.columns:
    if is_numeric_dtype(col):
        continue
    else:
        x[col]=le.fit_transform(x[col])

# %%
x
# Out:
#    Outlook  Temprature  Routine
# 0        1           0        0
# 1        0           0        0
# 2        0           1        1
# 3        1           0        1
# 4        0           0        1
# 5        1           1        1
# 6        0           1        0
# 7        1           1        0

# %%
# sunny -> 1
# Cloudy -> 0
# cold -> 0
# warm -> 1
# Indoor -> 0
# Outdoor -> 1

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict([[1,0,0]]) # sunny, cold, Indoor
# Out:
# array(['No'], dtype=object)

# %%
clf.predict([[1,0,1]]) # sunny, cold , outdoor
# Out:
# array(['Yes'], dtype=object)

# %%
clf.predict([[1,1,1]]) # sunny, warm, outdoor
# Out:
# array(['No'], dtype=object)

# %%
from sklearn import tree
from matplotlib import pyplot as plt

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.6666666666666666, 0.875, 'X[1] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.5, 0.625, 'X[2] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3333333333333333, 0.375, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]')]

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(clf,feature_names=x.columns,rounded=True,filled=True)
# Out:
# [Text(0.6666666666666666, 0.875, 'Temprature <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.5, 0.625, 'Routine <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3333333333333333, 0.375, 'Outlook <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]')]
