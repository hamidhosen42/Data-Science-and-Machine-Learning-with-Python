# %% [markdown]
# # All about Feature Transformation

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./DataSet/supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.tail()
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 45          1000.23       124153.04    1903.93    Dhaka  64926.08
# 46          1315.46       115816.21  297114.46  Rangpur  49490.75
# 47             0.00       135426.92       0.00      Ctg  42559.73
# 48           542.05        51743.15       0.00    Dhaka  35673.41
# 49             0.00       116983.80   45173.06      Ctg  14681.40

# %%
df.shape
# Out:
# (50, 5)

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['Marketing Spend'],y=df['Profit'])
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Profit'>

# %%
sns.scatterplot(x=df['Marketing Spend'],y=df['Administration'],color='red',markers='+')
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Administration'>

# %%
sns.scatterplot(x=df['Marketing Spend'],y=df['Transport'],color='red',markers='+')
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Transport'>

# %%
sns.scatterplot(x=df['Marketing Spend'],y=df['Area'],color='red',markers='+')
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Area'>

# %%
df1=df.copy()
df2=df.copy()
df3=df.copy()
df4=df.copy()

# %% [markdown]
# # Normalization

# %%
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

from sklearn.preprocessing import MinMaxScaler

# %%
# m=MinMaxScaler(feature_range=(10,15))
m=MinMaxScaler()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df.columns:
    if is_numeric_dtype(df[i]):
        df[i]=m.fit_transform(df[[i]])

# %%
# ms1=m.fit(df[['Marketing Spend']])
# ms2=m.fit(df[['Administration']])
# ms3=m.fit(df[['Transport']])

# %%
# print(ms1,ms2,ms3,ms4)

# %%
# m.data_max_
# m.data_min_
# m.data_range_

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
# m.transform(df[['Marketing Spend']])

# %%
# df['Marketing Spend']=m.transform(df[['Marketing Spend']])
# df['Administration']=m.transform(df[['Administration']])
# df['Transport']=m.transform(df[['Transport']])

# %%
df['Marketing Spend']=m.fit_transform(df[['Marketing Spend']])
df['Administration']=m.fit_transform(df[['Administration']])
df['Transport']=m.fit_transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
df[['Marketing Spend', 'Administration', 'Transport']] = m.fit_transform(df[['Marketing Spend', 'Administration', 'Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df2.columns:
    if is_numeric_dtype(df2[i]):
        df2[i]=scaler.fit_transform(df2[[i]])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %%
df2['Marketing Spend']=scaler.fit_transform(df2[['Marketing Spend']])
df2['Administration']=scaler.fit_transform(df2[['Administration']])
df2['Transport']=scaler.fit_transform(df2[['Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %%
df2[['Marketing Spend', 'Administration', 'Transport']] = scaler.fit_transform(df2[['Marketing Spend', 'Administration', 'Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
robust=RobustScaler()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df3.columns:
    if is_numeric_dtype(df3[i]):
        df3[i]=scaler.fit_transform(df3[[i]])

# %%
df3['Marketing Spend']=robust.fit_transform(df3[['Marketing Spend']])
df3['Administration']=robust.fit_transform(df3[['Administration']])
df3['Transport']=robust.fit_transform(df3[['Transport']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  2.011203
# 1         1.452113        0.697565   1.383714      Ctg  1.999430
# 2         1.303634       -0.524290   1.166654  Rangpur  1.980842
# 3         1.156567       -0.097977   1.017368    Dhaka  1.776627
# 4         1.119836       -0.761543   0.914576  Rangpur  1.357740

# %%
df3[['Marketing Spend', 'Administration', 'Transport']] = scaler.fit_transform(df3[['Marketing Spend', 'Administration', 'Transport']])

# %%
df3
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 0          0.897913        0.560753   2.165287    Dhaka  2.011203
# 1          1.955860        1.082807   1.929843      Ctg  1.999430
# 2          1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3          1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4          1.504937       -1.079919   1.273550  Rangpur  1.357740
# 5          1.279800       -0.776239   1.245627    Dhaka  1.127250
# 6          1.340066        0.932147  -0.739753      Ctg  1.105481
# 7          1.245057        0.871980   0.916470  Rangpur  1.096210
# 8          1.030369        0.986952   0.812928    Dhaka  1.007470
# 9          1.091819       -0.456640   0.756935      Ctg  0.946022
# 10         0.620398       -0.387599   0.116763  Rangpur  0.854847
# 11         0.593085       -1.065540   0.290555      Ctg  0.808168
# 12         0.443260        0.215449   0.291357  Rangpur  0.741155
# ...

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mx=MaxAbsScaler()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df4.columns:
    if is_numeric_dtype(df4[i]):
        df4[i]=scaler.fit_transform(df4[[i]])

# %%
df4['Marketing Spend']=mx.fit_transform(df4[['Marketing Spend']])
df4['Administration']=mx.fit_transform(df4[['Administration']])
df4['Transport']=mx.fit_transform(df4[['Transport']])

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.445303        0.221993   1.000000    Dhaka  2.011203
# 1         0.969971        0.428666   0.891264      Ctg  1.999430
# 2         0.870043       -0.288305   0.751028  Rangpur  1.980842
# 3         0.771065       -0.038149   0.654577    Dhaka  1.776627
# 4         0.746344       -0.427523   0.588166  Rangpur  1.357740

# %%
df4[['Marketing Spend', 'Administration', 'Transport']] = scaler.fit_transform(df4[['Marketing Spend', 'Administration', 'Transport']])

# %%
df4
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 0          0.897913        0.560753   2.165287    Dhaka  2.011203
# 1          1.955860        1.082807   1.929843      Ctg  1.999430
# 2          1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3          1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4          1.504937       -1.079919   1.273550  Rangpur  1.357740
# 5          1.279800       -0.776239   1.245627    Dhaka  1.127250
# 6          1.340066        0.932147  -0.739753      Ctg  1.105481
# 7          1.245057        0.871980   0.916470  Rangpur  1.096210
# 8          1.030369        0.986952   0.812928    Dhaka  1.007470
# 9          1.091819       -0.456640   0.756935      Ctg  0.946022
# 10         0.620398       -0.387599   0.116763  Rangpur  0.854847
# 11         0.593085       -1.065540   0.290555      Ctg  0.808168
# 12         0.443260        0.215449   0.291357  Rangpur  0.741155
# ...
